# %%
# !git clone https://github.com/mikejrodd/grapeleafGPT
# Out:
# Cloning into 'grapeleafGPT'...
# remote: Enumerating objects: 629, done.
# remote: Counting objects: 100% (628/628), done.
# remote: Compressing objects: 100% (425/425), done.
# remote: Total 629 (delta 371), reused 370 (delta 197), pack-reused 1
# Receiving objects: 100% (629/629), 41.16 MiB | 10.92 MiB/s, done.
# Resolving deltas: 100% (371/371), done.

# %%
# %cd /content/grapeleafGPT
# !pip install -r requirements.txt
# Out:
# /content/grapeleafGPT
# Collecting deepspeed==0.9.2 (from -r requirements.txt (line 1))
#   Downloading deepspeed-0.9.2.tar.gz (779 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.3/779.3 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting easydict==1.10 (from -r requirements.txt (line 2))
#   Downloading easydict-1.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting einops==0.6.1 (from -r requirements.txt (line 3))
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
# Collecting ftfy==6.1.1 (from -r requirements.txt (line 4))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 9.0 MB/s eta 0:00:00
# Collecting gradio==3.41.2 (from -r requirements.txt (line 5))
#   Downloading gradio-3.41.2-py3-none-any.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 68.9 MB/s eta 0:00:00
# Requirement already satisfied: h5py==3.9.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.9.0)
# Collecting iopath==0.1.10 (from -r requirements.txt (line 7))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ipdb==0.13.13 (from -r requirements.txt (line 8))
#   Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Collecting kornia==0.7.0 (from -r requirements.txt (line 9))
#   Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 36.1 MB/s eta 0:00:00
# Collecting matplotlib==3.7.2 (from -r requirements.txt (line 10))
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 59.6 MB/s eta 0:00:00
# Collecting mdtex2html==1.2.0 (from -r requirements.txt (line 11))
#   Downloading mdtex2html-1.2.0-py3-none-any.whl (13 kB)
# Collecting numpy==1.24.3 (from -r requirements.txt (line 12))
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 78.2 MB/s eta 0:00:00
# Collecting open3d_python==0.3.0.0 (from -r requirements.txt (line 13))
#   Downloading open3d_python-0.3.0.0-py2.py3-none-any.whl (17.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 62.5 MB/s eta 0:00:00
# Collecting opencv_python==4.8.0.74 (from -r requirements.txt (line 14))
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 28.5 MB/s eta 0:00:00
# Collecting peft==0.3.0 (from -r requirements.txt (line 15))
#   Downloading peft-0.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 8.6 MB/s eta 0:00:00
# Collecting Pillow==10.0.0 (from -r requirements.txt (line 16))
#   Downloading Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 97.6 MB/s eta 0:00:00
# Collecting pytorchvideo==0.1.5 (from -r requirements.txt (line 17))
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 18)) (6.0.1)
# Collecting regex==2022.10.31 (from -r requirements.txt (line 19))
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 63.8 MB/s eta 0:00:00
# Collecting scikit_learn==1.3.0 (from -r requirements.txt (line 20))
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 122.3 MB/s eta 0:00:00
# Collecting termcolor==2.3.0 (from -r requirements.txt (line 21))
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting timm==0.6.7 (from -r requirements.txt (line 22))
#   Downloading timm-0.6.7-py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 kB 50.0 MB/s eta 0:00:00
# Collecting tqdm==4.64.1 (from -r requirements.txt (line 26))
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 12.6 MB/s eta 0:00:00
# Collecting transformers==4.29.1 (from -r requirements.txt (line 27))
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 81.8 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 28)) (0.1.99)
# Collecting hjson (from deepspeed==0.9.2->-r requirements.txt (line 1))
#   Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 8.1 MB/s eta 0:00:00
# Collecting ninja (from deepspeed==0.9.2->-r requirements.txt (line 1))
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.2->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.2->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.2->-r requirements.txt (line 1)) (9.0.0)
# Collecting pydantic<2.0.0 (from deepspeed==0.9.2->-r requirements.txt (line 1))
#   Downloading pydantic-1.10.17-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.2->-r requirements.txt (line 1)) (2.3.0+cu121)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1->-r requirements.txt (line 4)) (0.2.13)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (4.2.2)
# Collecting fastapi (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.4 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.5.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading gradio_client-0.5.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 35.3 MB/s eta 0:00:00
# Collecting httpx (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (2.1.5)
# Collecting orjson~=3.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (2.0.3)
# Collecting pydub (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements.txt (line 5)) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.4 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.7 MB/s eta 0:00:00
# Collecting portalocker (from iopath==0.1.10->-r requirements.txt (line 7))
#   Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 8)) (7.34.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 10)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 10)) (1.4.5)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib==3.7.2->-r requirements.txt (line 10))
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from mdtex2html==1.2.0->-r requirements.txt (line 11)) (3.6)
# Collecting latex2mathml (from mdtex2html==1.2.0->-r requirements.txt (line 11))
#   Downloading latex2mathml-3.77.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 11.0 MB/s eta 0:00:00
# Collecting accelerate (from peft==0.3.0->-r requirements.txt (line 15))
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 36.5 MB/s eta 0:00:00
# Collecting fvcore (from pytorchvideo==0.1.5->-r requirements.txt (line 17))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo==0.1.5->-r requirements.txt (line 17))
#   Downloading av-12.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 50.6 MB/s eta 0:00:00
# Collecting parameterized (from pytorchvideo==0.1.5->-r requirements.txt (line 17))
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5->-r requirements.txt (line 17)) (3.3)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.3.0->-r requirements.txt (line 20)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.3.0->-r requirements.txt (line 20)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.3.0->-r requirements.txt (line 20)) (3.5.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.6.7->-r requirements.txt (line 22)) (0.18.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.29.1->-r requirements.txt (line 27)) (3.15.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.29.1->-r requirements.txt (line 27))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.5.0->gradio==3.41.2->-r requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.41.2->-r requirements.txt (line 5)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.41.2->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.2->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.41.2->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.41.2->-r requirements.txt (line 5)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.41.2->-r requirements.txt (line 5)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.41.2->-r requirements.txt (line 5)) (2024.6.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed==0.9.2->-r requirements.txt (line 1)) (1.12.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed==0.9.2->-r requirements.txt (line 1)) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->deepspeed==0.9.2->-r requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 71.9 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5)) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->peft==0.3.0->-r requirements.txt (line 15)) (0.4.3)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.8 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.8 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.41.2->-r requirements.txt (line 5)) (3.7.1)
# Collecting httpcore==1.* (from httpx->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.41.2->-r requirements.txt (line 5)) (1.3.1)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo==0.1.5->-r requirements.txt (line 17))
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5->-r requirements.txt (line 17)) (0.9.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi->gradio==3.41.2->-r requirements.txt (line 5)) (0.12.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->gradio==3.41.2->-r requirements.txt (line 5)) (1.2.1)
# Collecting httptools>=0.5.0 (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 36.8 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 107.0 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements.txt (line 5))
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepspeed==0.9.2->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.41.2->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.41.2->-r requirements.txt (line 5)) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.41.2->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.41.2->-r requirements.txt (line 5)) (0.1.2)
# Building wheels for collected packages: deepspeed, easydict, iopath, pytorchvideo, ffmpy, fvcore
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.9.2-py3-none-any.whl size=811218 sha256=35b92bf69a7de8315893856764ff25e7b8abe7ec508b11ba439ae89d1179ebd4
#   Stored in directory: /root/.cache/pip/wheels/a6/d2/b1/b15210b5dc024bab4eccbac2148db29959fe01fe6042557d07
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.10-py3-none-any.whl size=6491 sha256=de136f55c8f45131ce16a1c1a86cf8728c8da07465a7aa1b6ee685de4b714ac9
#   Stored in directory: /root/.cache/pip/wheels/b7/e3/8c/f814820ac7ef5fd96f38759ce0d3dc51166a3169008b31da53
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=5a98dd1d8ceb5e122633cc9c8b696e505cef0e5d36e1d69b1e1c86ffaeebc72a
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188685 sha256=62b6331185d982477923c1486329a435d4f58cfaee7304e2388cba38fc7053e9
#   Stored in directory: /root/.cache/pip/wheels/ff/4e/81/0f72a543be9ed7eb737c95bfc5da4025e73226b44368074ece
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=2f146ea349ad848d75388ccafbcb83094f6105419d63483d6abe39d6b5bd7884
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=bc29d3266427ac4b1ff9e1843a0db6e310d3e54ef66c2631c13f101297b7fda6
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
# Successfully built deepspeed easydict iopath pytorchvideo ffmpy fvcore
# Installing collected packages: tokenizers, pydub, ninja, hjson, ffmpy, easydict, yacs, websockets, uvloop, ujson, tqdm, termcolor, semantic-version, regex, python-multipart, python-dotenv, pyparsing, pydantic, portalocker, Pillow, parameterized, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, latex2mathml, jedi, httptools, h11, ftfy, einops, dnspython, av, aiofiles, watchfiles, uvicorn, starlette, opencv_python, open3d_python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mdtex2html, iopath, httpcore, email_validator, transformers, scikit_learn, nvidia-cusolver-cu12, matplotlib, ipdb, httpx, fvcore, pytorchvideo, gradio-client, fastapi-cli, kornia, fastapi, deepspeed, accelerate, timm, peft, gradio
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: easydict
#     Found existing installation: easydict 1.13
#     Uninstalling easydict-1.13:
#       Successfully uninstalled easydict-1.13
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.5.15
#     Uninstalling regex-2024.5.15:
#       Successfully uninstalled regex-2024.5.15
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.4
#     Uninstalling pydantic-2.7.4:
#       Successfully uninstalled pydantic-2.7.4
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: opencv_python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# Successfully installed Pillow-10.0.0 accelerate-0.31.0 aiofiles-23.2.1 av-12.2.0 deepspeed-0.9.2 dnspython-2.6.1 easydict-1.10 einops-0.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 ffmpy-0.3.2 ftfy-6.1.1 fvcore-0.1.5.post20221221 gradio-3.41.2 gradio-client-0.5.0 h11-0.14.0 hjson-3.1.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 iopath-0.1.10 ipdb-0.13.13 jedi-0.19.1 kornia-0.7.0 latex2mathml-3.77.0 matplotlib-3.7.2 mdtex2html-1.2.0 ninja-1.11.1.1 numpy-1.24.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 open3d_python-0.3.0.0 opencv_python-4.8.0.74 orjson-3.10.5 parameterized-0.9.0 peft-0.3.0 portalocker-2.10.0 pydantic-1.10.17 pydub-0.25.1 pyparsing-3.0.9 python-dotenv-1.0.1 python-multipart-0.0.9 pytorchvideo-0.1.5 regex-2022.10.31 scikit_learn-1.3.0 semantic-version-2.10.0 starlette-0.37.2 termcolor-2.3.0 timm-0.6.7 tokenizers-0.13.3 tqdm-4.64.1 transformers-4.29.1 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-11.0.3 yacs-0.1.8

# %%
# !pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Collecting torch==1.13.1+cu117
#   Downloading https://download.pytorch.org/whl/cu117/torch-1.13.1%2Bcu117-cp310-cp310-linux_x86_64.whl (1801.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 991.4 kB/s eta 0:00:00
# Collecting torchvision==0.14.1+cu117
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.14.1%2Bcu117-cp310-cp310-linux_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 66.1 MB/s eta 0:00:00
# Collecting torchaudio==0.13.1
#   Downloading https://download.pytorch.org/whl/cu117/torchaudio-0.13.1%2Bcu117-cp310-cp310-linux_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 98.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1+cu117) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (10.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (2024.6.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
#       Successfully uninstalled torchvision-0.18.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.3.0+cu121
#     Uninstalling torchaudio-2.3.0+cu121:
#       Successfully uninstalled torchaudio-2.3.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1+cu117 which is incompatible.
# Successfully installed torch-1.13.1+cu117 torchaudio-0.13.1+cu117 torchvision-0.14.1+cu117

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/grapeleafGPT/pretrained_ckpt/imagebind_ckpt
# !ln -s /content/drive/MyDrive/gtprac/imagebind_huge.pth /content/grapeleafGPT/pretrained_ckpt/imagebind_ckpt/imagebind_huge.pth

# %%
# !mkdir -p /content/grapeleafGPT/pretrained_ckpt/vicuna_ckpt/7b_v0
# !ln -s /content/drive/MyDrive/gtprac/7b_v0/* /content/grapeleafGPT/pretrained_ckpt/vicuna_ckpt/7b_v0/

# %%
# !mkdir -p /content/grapeleafGPT/pretrained_ckpt/pandagpt_ckpt/7b
# !ln -s /content/drive/MyDrive/gtprac/pytorch_model.pt /content/grapeleafGPT/pretrained_ckpt/pandagpt_ckpt/7b/pytorch_model.pt

# %%
# !mkdir -p /content/grapeleafGPT/code/ckpt/train_grapeleaves
# !ln -s /content/drive/MyDrive/gtprac/final_model_grapeleafGPT/* /content/grapeleafGPT/code/ckpt/train_grapeleaves/

# %%
# %cd /content/grapeleafGPT/code
# !python web_demo.py
# Out:
# /content/grapeleafGPT/code
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# Initializing visual encoder from ../pretrained_ckpt/imagebind_ckpt/imagebind_huge.pth ...
# Visual encoder initialized.
# Initializing language decoder from ../pretrained_ckpt/vicuna_ckpt/7b_v0 ...
# Loading checkpoint shards: 100% 3/3 [06:24<00:00, 128.01s/it]
# Some weights of LlamaForCausalLM were not initialized from the model checkpoint at ../pretrained_ckpt/vicuna_ckpt/7b_v0 and are newly initialized: ['model.layers.10.self_attn.rotary_emb.inv_freq', 'model.layers.21.self_attn.rotary_emb.inv_freq', 'model.layers.2.self_attn.rotary_emb.inv_freq', 'model.layers.6.self_attn.rotary_emb.inv_freq', 'model.layers.18.self_attn.rotary_emb.inv_freq', 'model.layers.27.self_attn.rotary_emb.inv_freq', 'model.layers.30.self_attn.rotary_emb.inv_freq', 'model.layers.7.self_attn.rotary_emb.inv_freq', 'model.layers.22.self_attn.rotary_emb.inv_freq', 'model.layers.14.self_attn.rotary_emb.inv_freq', 'model.layers.1.self_attn.rotary_emb.inv_freq', 'model.layers.17.self_attn.rotary_emb.inv_freq', 'model.layers.0.self_attn.rotary_emb.inv_freq', 'model.layers.5.self_attn.rotary_emb.inv_freq', 'model.layers.31.self_attn.rotary_emb.inv_freq', 'model.layers.3.self_attn.rotary_emb.inv_freq', 'model.layers.28.self_attn.rotary_emb.inv_freq', 'model.layers.12.self_attn.rotary_emb.inv_freq', 'model.layers.29.self_attn.rotary_emb.inv_freq', 'model.layers.13.self_attn.rotary_emb.inv_freq', 'model.layers.24.self_attn.rotary_emb.inv_freq', 'model.layers.8.self_attn.rotary_emb.inv_freq', 'model.layers.16.self_attn.rotary_emb.inv_freq', 'model.layers.20.self_attn.rotary_emb.inv_freq', 'model.layers.9.self_attn.rotary_emb.inv_freq', 'model.layers.25.self_attn.rotary_emb.inv_freq', 'model.layers.26.self_attn.rotary_emb.inv_freq', 'model.layers.15.self_attn.rotary_emb.inv_freq', 'model.layers.23.self_attn.rotary_emb.inv_freq', 'model.layers.4.self_attn.rotary_emb.inv_freq', 'model.layers.19.self_attn.rotary_emb.inv_freq', 'model.layers.11.self_attn.rotary_emb.inv_freq']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# trainable params: 33554432 || all params: 6771978240 || trainable%: 0.49548936530546206
# Language decoder initialized.
# /content/grapeleafGPT/code/web_demo.py:177: GradioUnusedKwargWarning: You have unused kwarg parameters in Row, please remove them: {'scale': 3}
#   with gr.Row(scale=3):
# /content/grapeleafGPT/code/web_demo.py:179: GradioUnusedKwargWarning: You have unused kwarg parameters in Row, please remove them: {'scale': 3}
#   with gr.Row(scale=3):
# /content/grapeleafGPT/code/web_demo.py:192: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   chatbot = gr.Chatbot().style(height=415)
# /content/grapeleafGPT/code/web_demo.py:197: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   user_input = gr.Textbox(show_label=False, placeholder="Input...", lines=10).style(container=False)
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 3.41.2, however version 4.29.0 is available, please upgrade.
# --------
# Running on public URL: https://4ce74bc212b65d7c38.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# [!] image path: /tmp/gradio/7d35a6e932ecaf71232677c15cb85c29dfa66a47/image.png
# [!] normal image path: None
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1255: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# 2024-07-02 10:07:31.151964: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 10:07:31.152016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 10:07:31.263925: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-02 10:07:32.505806: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [!] image path: /tmp/gradio/3631e66b7746a572bbece3563da05908f64af354/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/3631e66b7746a572bbece3563da05908f64af354/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/c44b481cdeab1d9f7cf8e2c78109239f27dc7678/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/c44b481cdeab1d9f7cf8e2c78109239f27dc7678/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/60b42cd227a222a3439de93f2af118b1a47b1057/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/60b42cd227a222a3439de93f2af118b1a47b1057/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/60b42cd227a222a3439de93f2af118b1a47b1057/image.png
# [!] normal image path: None
#
# [!] image path: /tmp/gradio/60b42cd227a222a3439de93f2af118b1a47b1057/image.png
# [!] normal image path: None
#
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://4ce74bc212b65d7c38.gradio.live
